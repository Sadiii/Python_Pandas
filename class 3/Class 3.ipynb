# %% [markdown]
# ### Columns
# - renaming (single, few columns, all columns)

# %%
import pandas as pd

# %%
df = pd.read_csv('data/population.csv')
df
# Out:
#      Series Code        Country Name Country Code     2018 [YR2018]
# 0    EN.POP.DNST         Afghanistan          AFG   56.937760009803
# 1    EN.POP.DNST             Albania          ALB  104.612262773723
# 2    EN.POP.DNST             Algeria          DZA  17.7300676270006
# 3    EN.POP.DNST      American Samoa          ASM           277.325
# 4    EN.POP.DNST             Andorra          AND  163.842553191489
# ..           ...                 ...          ...               ...
# 210  EN.POP.DNST  West Bank and Gaza          PSE  758.984551495017
# 211  EN.POP.DNST         Yemen, Rep.          YEM  53.9778529083092
# 212  EN.POP.DNST              Zambia          ZMB  23.3414789007116
# 213  EN.POP.DNST            Zimbabwe          ZWE  37.3245909267158
# 214  EN.POP.DNST               World          WLD  58.4223714971078
#
# [215 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Series Code', 'Country Name', 'Country Code', '2018 [YR2018]'], dtype='object')

# %%
df.rename(columns = {'2018 [YR2018]':'YR 2018'}, inplace = True)

# %%
df
# Out:
#      Series Code        Country Name Country Code           YR 2018
# 0    EN.POP.DNST         Afghanistan          AFG   56.937760009803
# 1    EN.POP.DNST             Albania          ALB  104.612262773723
# 2    EN.POP.DNST             Algeria          DZA  17.7300676270006
# 3    EN.POP.DNST      American Samoa          ASM           277.325
# 4    EN.POP.DNST             Andorra          AND  163.842553191489
# ..           ...                 ...          ...               ...
# 210  EN.POP.DNST  West Bank and Gaza          PSE  758.984551495017
# 211  EN.POP.DNST         Yemen, Rep.          YEM  53.9778529083092
# 212  EN.POP.DNST              Zambia          ZMB  23.3414789007116
# 213  EN.POP.DNST            Zimbabwe          ZWE  37.3245909267158
# 214  EN.POP.DNST               World          WLD  58.4223714971078
#
# [215 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Series Code', 'Country Name', 'Country Code', 'YR 2018'], dtype='object')

# %%
df.rename(columns = {'Series Code':'Code','YR 2018':'Year 2018'}, inplace = True)

# %%
df
# Out:
#             Code        Country Name Country Code         Year 2018
# 0    EN.POP.DNST         Afghanistan          AFG   56.937760009803
# 1    EN.POP.DNST             Albania          ALB  104.612262773723
# 2    EN.POP.DNST             Algeria          DZA  17.7300676270006
# 3    EN.POP.DNST      American Samoa          ASM           277.325
# 4    EN.POP.DNST             Andorra          AND  163.842553191489
# ..           ...                 ...          ...               ...
# 210  EN.POP.DNST  West Bank and Gaza          PSE  758.984551495017
# 211  EN.POP.DNST         Yemen, Rep.          YEM  53.9778529083092
# 212  EN.POP.DNST              Zambia          ZMB  23.3414789007116
# 213  EN.POP.DNST            Zimbabwe          ZWE  37.3245909267158
# 214  EN.POP.DNST               World          WLD  58.4223714971078
#
# [215 rows x 4 columns]

# %%
df.rename(columns = {'Code':'Series Code','Year 2018':'YR 2018'}, inplace = True)

# %%
df
# Out:
#      Series Code        Country Name Country Code           YR 2018
# 0    EN.POP.DNST         Afghanistan          AFG   56.937760009803
# 1    EN.POP.DNST             Albania          ALB  104.612262773723
# 2    EN.POP.DNST             Algeria          DZA  17.7300676270006
# 3    EN.POP.DNST      American Samoa          ASM           277.325
# 4    EN.POP.DNST             Andorra          AND  163.842553191489
# ..           ...                 ...          ...               ...
# 210  EN.POP.DNST  West Bank and Gaza          PSE  758.984551495017
# 211  EN.POP.DNST         Yemen, Rep.          YEM  53.9778529083092
# 212  EN.POP.DNST              Zambia          ZMB  23.3414789007116
# 213  EN.POP.DNST            Zimbabwe          ZWE  37.3245909267158
# 214  EN.POP.DNST               World          WLD  58.4223714971078
#
# [215 rows x 4 columns]

# %%
df.columns = ['Series_Code', 'Country_Name', 'Country_Code', 'YR_2018']

# %%
df
# Out:
#      Series_Code        Country_Name Country_Code           YR_2018
# 0    EN.POP.DNST         Afghanistan          AFG   56.937760009803
# 1    EN.POP.DNST             Albania          ALB  104.612262773723
# 2    EN.POP.DNST             Algeria          DZA  17.7300676270006
# 3    EN.POP.DNST      American Samoa          ASM           277.325
# 4    EN.POP.DNST             Andorra          AND  163.842553191489
# ..           ...                 ...          ...               ...
# 210  EN.POP.DNST  West Bank and Gaza          PSE  758.984551495017
# 211  EN.POP.DNST         Yemen, Rep.          YEM  53.9778529083092
# 212  EN.POP.DNST              Zambia          ZMB  23.3414789007116
# 213  EN.POP.DNST            Zimbabwe          ZWE  37.3245909267158
# 214  EN.POP.DNST               World          WLD  58.4223714971078
#
# [215 rows x 4 columns]

# %%
df.columns = df.columns.str.replace('_',' ')

# %%
df
# Out:
#      Series Code        Country Name Country Code           YR 2018
# 0    EN.POP.DNST         Afghanistan          AFG   56.937760009803
# 1    EN.POP.DNST             Albania          ALB  104.612262773723
# 2    EN.POP.DNST             Algeria          DZA  17.7300676270006
# 3    EN.POP.DNST      American Samoa          ASM           277.325
# 4    EN.POP.DNST             Andorra          AND  163.842553191489
# ..           ...                 ...          ...               ...
# 210  EN.POP.DNST  West Bank and Gaza          PSE  758.984551495017
# 211  EN.POP.DNST         Yemen, Rep.          YEM  53.9778529083092
# 212  EN.POP.DNST              Zambia          ZMB  23.3414789007116
# 213  EN.POP.DNST            Zimbabwe          ZWE  37.3245909267158
# 214  EN.POP.DNST               World          WLD  58.4223714971078
#
# [215 rows x 4 columns]

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#      SERIES CODE        COUNTRY NAME COUNTRY CODE           YR 2018
# 0    EN.POP.DNST         Afghanistan          AFG   56.937760009803
# 1    EN.POP.DNST             Albania          ALB  104.612262773723
# 2    EN.POP.DNST             Algeria          DZA  17.7300676270006
# 3    EN.POP.DNST      American Samoa          ASM           277.325
# 4    EN.POP.DNST             Andorra          AND  163.842553191489
# ..           ...                 ...          ...               ...
# 210  EN.POP.DNST  West Bank and Gaza          PSE  758.984551495017
# 211  EN.POP.DNST         Yemen, Rep.          YEM  53.9778529083092
# 212  EN.POP.DNST              Zambia          ZMB  23.3414789007116
# 213  EN.POP.DNST            Zimbabwe          ZWE  37.3245909267158
# 214  EN.POP.DNST               World          WLD  58.4223714971078
#
# [215 rows x 4 columns]

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df
# Out:
#      series code        country name country code           yr 2018
# 0    EN.POP.DNST         Afghanistan          AFG   56.937760009803
# 1    EN.POP.DNST             Albania          ALB  104.612262773723
# 2    EN.POP.DNST             Algeria          DZA  17.7300676270006
# 3    EN.POP.DNST      American Samoa          ASM           277.325
# 4    EN.POP.DNST             Andorra          AND  163.842553191489
# ..           ...                 ...          ...               ...
# 210  EN.POP.DNST  West Bank and Gaza          PSE  758.984551495017
# 211  EN.POP.DNST         Yemen, Rep.          YEM  53.9778529083092
# 212  EN.POP.DNST              Zambia          ZMB  23.3414789007116
# 213  EN.POP.DNST            Zimbabwe          ZWE  37.3245909267158
# 214  EN.POP.DNST               World          WLD  58.4223714971078
#
# [215 rows x 4 columns]
