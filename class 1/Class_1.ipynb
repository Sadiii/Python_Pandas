# %% [markdown]
# - Importing Data
# - Displaying data
# - Shapes
# - info()
# - basic statistics (describe)
# - play with columns and rows
# - indexing (fetching, changing)
# - slicing

# %%
import pandas as pd

# %%
df = pd.read_csv("data/covidcases.csv")

# %%
df
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                 109217366
# 1    United States of America         Americas                  27433718
# 2                       India  South-East Asia                  10937320
# 3                      Brazil         Americas                   9866710
# 4          Russian Federation           Europe                   4112151
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 100000 population  \
# ...

# %%
df.head(70)
# Out:
#                         Name       WHO Region  Cases - cumulative total  \
# 0                     Global              NaN                 109217366
# 1   United States of America         Americas                  27433718
# 2                      India  South-East Asia                  10937320
# 3                     Brazil         Americas                   9866710
# 4         Russian Federation           Europe                   4112151
# ..                       ...              ...                       ...
# 65                    Greece           Europe                    173905
# 66       Republic of Moldova           Europe                    171514
# 67                   Armenia           Europe                    169597
# 68                 Guatemala         Americas                    168103
# 69                  Honduras         Americas                    160983
#
#     Cases - cumulative total per 100000 population  \
# ...

# %%
df.tail(1)
# Out:
#        Name       WHO Region  Cases - cumulative total  \
# 237  Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 100000 population  \
# 237                                             0.0
#
#      Cases - newly reported in last 7 days  \
# 237                                      0
#
#      Cases - newly reported in last 7 days per 100000 population  \
# 237                                                0.0
#
#      Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 237                                        0                          0
#
#      Deaths - cumulative total per 100000 population  \
# 237                                              0.0
#
#      Deaths - newly reported in last 7 days  \
# 237                                       0
#
#      Deaths - newly reported in last 7 days per 100000 population  \
# 237                                                0.0
#
# ...

# %%
#pd.set_option('display.max_rows', 238)

# %%
df
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                 109217366
# 1    United States of America         Americas                  27433718
# 2                       India  South-East Asia                  10937320
# 3                      Brazil         Americas                   9866710
# 4          Russian Federation           Europe                   4112151
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 100000 population  \
# ...

# %%
df.shape
# Out:
# (238, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Name                                                          238 non-null    object
#  1   WHO Region                                                    237 non-null    object
#  2   Cases - cumulative total                                      238 non-null    int64
#  3   Cases - cumulative total per 100000 population                237 non-null    float64
#  4   Cases - newly reported in last 7 days                         238 non-null    int64
#  5   Cases - newly reported in last 7 days per 100000 population   237 non-null    float64
#  6   Cases - newly reported in last 24 hours                       238 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Cases - cumulative total  \
# count              2.380000e+02
# mean               9.177930e+05
# std                7.351324e+06
# min                0.000000e+00
# 25%                1.990500e+03
# 50%                2.021800e+04
# 75%                1.979732e+05
# max                1.092174e+08
#
#        Cases - cumulative total per 100000 population  \
# count                                      237.000000
# mean                                      2106.920087
# std                                       2614.276829
# min                                          0.000000
# 25%                                        113.350000
# 50%                                       1022.330000
# 75%                                       3542.400000
# max                                      13660.780000
#
#        Cases - newly reported in last 7 days  \
# count                           2.380000e+02
# mean                            2.199757e+04
# ...

# %% [markdown]
# #### Columns

# %%
df.columns
# Out:
# Index(['Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours',
#        'Transmission Classification'],
#       dtype='object')

# %%
df[['Name', 'WHO Region', 'Cases - cumulative total']]
# Out:
#                          Name       WHO Region  Cases - cumulative total
# 0                      Global              NaN                 109217366
# 1    United States of America         Americas                  27433718
# 2                       India  South-East Asia                  10937320
# 3                      Brazil         Americas                   9866710
# 4          Russian Federation           Europe                   4112151
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
# [238 rows x 3 columns]

# %%
type(df.Name)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.Name
# Out:
# 0                        Global
# 1      United States of America
# 2                         India
# 3                        Brazil
# 4            Russian Federation
#                  ...
# 233                Saint Helena
# 234                     Tokelau
# 235                       Tonga
# 236                Turkmenistan
# 237                      Tuvalu
# Name: Name, Length: 238, dtype: object

# %%
df["WHO Region"]
# Out:
# 0                  NaN
# 1             Americas
# 2      South-East Asia
# 3             Americas
# 4               Europe
#             ...
# 233             Africa
# 234    Western Pacific
# 235    Western Pacific
# 236             Europe
# 237    Western Pacific
# Name: WHO Region, Length: 238, dtype: object

# %%
df.set_index('Name', inplace  = True)

# %%
df
# Out:
#                                WHO Region  Cases - cumulative total  \
# Name
# Global                                NaN                 109217366
# United States of America         Americas                  27433718
# India                     South-East Asia                  10937320
# Brazil                           Americas                   9866710
# Russian Federation                 Europe                   4112151
# ...                                   ...                       ...
# Saint Helena                       Africa                         0
# Tokelau                   Western Pacific                         0
# Tonga                     Western Pacific                         0
# Turkmenistan                       Europe                         0
# Tuvalu                    Western Pacific                         0
#
#                           Cases - cumulative total per 100000 population  \
# Name
# ...

# %%
df = df[['WHO Region', 'Cases - cumulative total']]

# %%
df
# Out:
#                                WHO Region  Cases - cumulative total
# Name
# Global                                NaN                 109217366
# United States of America         Americas                  27433718
# India                     South-East Asia                  10937320
# Brazil                           Americas                   9866710
# Russian Federation                 Europe                   4112151
# ...                                   ...                       ...
# Saint Helena                       Africa                         0
# Tokelau                   Western Pacific                         0
# Tonga                     Western Pacific                         0
# Turkmenistan                       Europe                         0
# Tuvalu                    Western Pacific                         0
#
# [238 rows x 2 columns]

# %%
df.reset_index()
# Out:
#                          Name       WHO Region  Cases - cumulative total
# 0                      Global              NaN                 109217366
# 1    United States of America         Americas                  27433718
# 2                       India  South-East Asia                  10937320
# 3                      Brazil         Americas                   9866710
# 4          Russian Federation           Europe                   4112151
# ..                        ...              ...                       ...
# 233              Saint Helena           Africa                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
# [238 rows x 3 columns]
